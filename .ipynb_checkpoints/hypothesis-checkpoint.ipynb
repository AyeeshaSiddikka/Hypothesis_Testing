# %% [markdown]
# # Before you start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas

import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1 - Exploring the Data
#
# In this challenge, we will examine all salaries of employees of the City of Chicago. We will start by loading the dataset and examining its contents.

# %%
# Your code here:
employees = pd.read_csv('/Users/ayeesha/IH-Labs/Hypothesis_Testing/Current_Employee_Names__Salaries__and_Position_Titles.csv')
employees.head(10)
# Out:
#                       Name                               Job Titles  \
# 0   ADRIANO,  RACQUEL ANNE                                PARAMEDIC
# 1        AFFANEH,  MAHIR A                           POLICE OFFICER
# 2        AFOENYI,  PHYLLIS                TITLE V PROGRAM TRAINEE I
# 3          AGAR,  BULENT B                      DEPUTY COMMISSIONER
# 4          AGEE,  LAWRENCE                           POLICE OFFICER
# 5        AGNEW,  ANTONIO E                       MOTOR TRUCK DRIVER
# 6        AGNEW,  MELISSA M                                 SERGEANT
# 7        AGOSTA,  JOSEPH J   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 8  AGOSTINELLI,  MICHAEL A  FIREFIGHTER (PER ARBITRATORS AWARD)-EMT
# 9        AGOSTINI,  LUIS R                                 ASST DIR
#
#          Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 0              FIRE                 F           Salary            NaN
# 1            POLICE                 F           Salary            NaN
# 2  FAMILY & SUPPORT                 P           Hourly           20.0
# 3       WATER MGMNT                 F           Salary            NaN
# 4            POLICE                 F           Salary            NaN
# 5          AVIATION                 F           Hourly           40.0
# 6            POLICE                 F           Salary            NaN
# 7            POLICE                 F           Salary            NaN
# 8              FIRE                 F           Salary            NaN
# 9            POLICE                 F           Salary            NaN
#
#    Annual Salary  Hourly Rate
# 0        72510.0          NaN
# 1        93354.0          NaN
# 2            NaN        13.00
# 3       132972.0          NaN
# 4        90024.0          NaN
# 5            NaN        37.45
# 6       111444.0          NaN
# 7       103932.0          NaN
# 8       107106.0          NaN
# 9        95736.0          NaN

# %% [markdown]
# Examine the `salaries` dataset using the `head` function below.

# %%
cols = []
for column in employees.columns:
    cols.append(column.lower())
employees.columns = cols

employees.columns = employees.columns.str.replace(' ', '_')

display(employees.head())
# Out:
#                      name                 job_titles        department  \
# 0  ADRIANO,  RACQUEL ANNE                  PARAMEDIC              FIRE
# 1       AFFANEH,  MAHIR A             POLICE OFFICER            POLICE
# 2       AFOENYI,  PHYLLIS  TITLE V PROGRAM TRAINEE I  FAMILY & SUPPORT
# 3         AGAR,  BULENT B        DEPUTY COMMISSIONER       WATER MGMNT
# 4         AGEE,  LAWRENCE             POLICE OFFICER            POLICE
#
#   full_or_part-time salary_or_hourly  typical_hours  annual_salary  \
# 0                 F           Salary            NaN        72510.0
# 1                 F           Salary            NaN        93354.0
# 2                 P           Hourly           20.0            NaN
# 3                 F           Salary            NaN       132972.0
# 4                 F           Salary            NaN        90024.0
#
#    hourly_rate
# 0          NaN
# 1          NaN
# 2         13.0
# 3          NaN
# 4          NaN

# %%
# Your code here:

employees['annual_salary'].head()
# Out:
# 0     72510.0
# 1     93354.0
# 2         NaN
# 3    132972.0
# 4     90024.0
# Name: annual_salary, dtype: float64

# %% [markdown]
# We see from looking at the `head` function that there is quite a bit of missing data. Let's examine how much missing data is in each column. Produce this output in the cell below

# %%
# Your code here:

employees.isnull().sum()
# Out:
# name                     0
# job_titles               0
# department               0
# full_or_part-time        0
# salary_or_hourly         0
# typical_hours        25528
# annual_salary         8174
# hourly_rate          25528
# dtype: int64

# %%
print(f"Total NaN in a datframe are : {employees.isnull().sum().sum()}")
# Out:
# Total NaN in a datframe are : 59230

# %% [markdown]
# Let's also look at the count of hourly vs. salaried employees. Write the code in the cell below

# %%
# Your code here:
employees['salary_or_hourly'].value_counts(dropna=False)
# Out:
# Salary    25528
# Hourly     8174
# Name: salary_or_hourly, dtype: int64

# %% [markdown]
# What this information indicates is that the table contains information about two types of employees - salaried and hourly. Some columns apply only to one type of employee while other columns only apply to another kind. This is why there are so many missing values. Therefore, we will not do anything to handle the missing values.

# %% [markdown]
# There are different departments in the city. List all departments and the count of employees in each department.

# %%
# Your code here:

employees.pivot_table(index=['department'], aggfunc={'department':'count'})
# Out:
#                      department
# department
# ADMIN HEARNG                 38
# ANIMAL CONTRL                75
# AVIATION                   1856
# BOARD OF ELECTION           111
# BOARD OF ETHICS               8
# BUDGET & MGMT                44
# BUILDINGS                   258
# BUSINESS AFFAIRS            167
# CITY CLERK                   88
# CITY COUNCIL                362
# COPA                        123
# CULTURAL AFFAIRS             74
# DAIS                       1033
# DISABILITIES                 28
# FAMILY & SUPPORT            656
# FINANCE                     544
# FIRE                       4627
# HEALTH                      467
# HOUSING                      66
# HOUSING & ECON DEV          154
# HUMAN RELATIONS              17
# HUMAN RESOURCES              75
# INSPECTOR GEN                95
# LAW                         398
# LICENSE APPL COMM             1
# MAYOR'S OFFICE              104
# OEMC                       1737
# POLICE                    13848
# POLICE BOARD                  2
# PROCUREMENT                  84
# PUBLIC LIBRARY             1088
# PUBLIC SAFETY ADMIN         244
# STREETS & SAN              2175
# TRANSPORTN                 1113
# TREASURER                    28
# WATER MGMNT                1914

# %% [markdown]
# # Challenge 2 - Hypothesis Tests
#
# In this section of the lab, we will test whether the hourly wage of all hourly workers is significantly different from $30/hr. Import the correct one sample test function from scipy and perform the hypothesis test for a 95% two sided confidence interval.

# %%
employees['hourly_rate'].mean()
# Out:
# 34.58644971862046

# %%
hourly_rate= employees[['hourly_rate']]
hourly_rate.dropna(inplace=True)
# Out:
# /var/folders/jz/1p9d4c1d34168vzv8v45354m0000gp/T/ipykernel_22548/263607297.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hourly_rate.dropna(inplace=True)

# %%
# Your code here:
from scipy.stats import ttest_1samp

# null hypothesis is all hourly workers have same $30/hr
# The alternative hypothesis is the hourly workers have different from $30/hr

mean = np.mean(hourly_rate)
print('Mean of hourly rate: ', mean)
std_dev = np.std(hourly_rate)
print('Standard Deviation of hourly rate: ', std_dev)

stat, pval = ttest_1samp(hourly_rate, 30)
print('stat is  ', stat)
print('pvalue for the two-tailed test is ', pval)

print('pvalue for the one-tailed test is ', pval/2)

"""The null hypothesis is rejected because the p-value is very low"""
# Out:
# Mean of hourly rate:  hourly_rate    34.58645
# dtype: float64
# Standard Deviation of hourly rate:  hourly_rate    13.28473
# dtype: float64
# stat is   [31.21150033]
# pvalue for the two-tailed test is  [3.82547585e-202]
# pvalue for the one-tailed test is  [1.91273792e-202]
# /Users/ayeesha/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3438: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# 'The null hypothesis is rejected because the p-value is very low'

# %% [markdown]
# We are also curious about salaries in the police force. The chief of police in Chicago claimed in a press briefing that salaries this year are higher than last year's mean of $86000/year a year for all salaried employees. Test this one sided hypothesis using a 95% confidence interval.
#
# Hint: A one tailed test has a p-value that is half of the two tailed p-value. If our hypothesis is greater than, then to reject, the test statistic must also be positive.

# %%
col = []
employees_df = employees.select_dtypes(object)
for col in employees.columns:
    print(col, ': ',employees[col].nunique())
    print(col, ': ',employees[col].unique())
# Out:
# name :  33380
# name :  ['ADRIANO,  RACQUEL ANNE' 'AFFANEH,  MAHIR A' 'AFOENYI,  PHYLLIS' ...
#  'ZYMANTAS,  MARK E' 'ZYRKOWSKI,  CARLO E' 'ZYSKOWSKI,  DARIUSZ']
# job_titles :  1119
# job_titles :  ['PARAMEDIC' 'POLICE OFFICER' 'TITLE V PROGRAM TRAINEE I' ...
#  'COORD OF PRINTING SERVICES - GRAPHICS' 'PHOTOGRAPHER'
#  'MECHANICAL ENGINEER IV']
# department :  36
# department :  ['FIRE' 'POLICE' 'FAMILY & SUPPORT' 'WATER MGMNT' 'AVIATION' 'TRANSPORTN'
#  'STREETS & SAN' 'FINANCE' 'LAW' 'CITY COUNCIL' 'DAIS' 'OEMC' 'COPA'
#  'HEALTH' 'BUSINESS AFFAIRS' 'HUMAN RESOURCES' 'PUBLIC LIBRARY'
#  'CULTURAL AFFAIRS' 'HOUSING' 'PROCUREMENT' 'BUILDINGS' 'ANIMAL CONTRL'
#  'CITY CLERK' 'HOUSING & ECON DEV' 'BOARD OF ELECTION'
#  'PUBLIC SAFETY ADMIN' 'DISABILITIES' 'INSPECTOR GEN' 'HUMAN RELATIONS'
#  "MAYOR'S OFFICE" 'TREASURER' 'BUDGET & MGMT' 'BOARD OF ETHICS'
#  'POLICE BOARD' 'ADMIN HEARNG' 'LICENSE APPL COMM']
# full_or_part-time :  2
# full_or_part-time :  ['F' 'P']
# salary_or_hourly :  2
# salary_or_hourly :  ['Salary' 'Hourly']
# typical_hours :  4
# typical_hours :  [nan 20. 40. 10. 35.]
# annual_salary :  924
# annual_salary :  [ 72510.    93354.         nan 132972.    90024.   111444.   103932.
#  107106.    95736.    94524.    48078.    67896.   122472.    84054.
#   89148.    92274.    47160.   143976.    94122.   118608.   117072.
#  103350.    56304.    87006.   105804.    94476.    99324.    64824.
#   91080.    68616.    76266.    67524.    82236.    80016.    72024.
#  111072.    74568.   103272.    89808.    98292.   100980.    78120.
#   48072.   121818.    60648.    93666.    96096.    70644.   175728.
#   72120.    96060.    58500.    73932.    64392.    87564.   107208.
#   46428.    84870.    67800.    79020.   132732.   102211.2   85704.
#  114948.    35124.   130092.    83628.    20568.    50412.   108072.
LICE OFFICER (ASSIGNED AS DETECTIVE)
# 9         AGOSTINI,  LUIS R                                ASST DIR
# ...                     ...                                     ...
# 33696  ZYLINSKA,  KATARZYNA                          POLICE OFFICER
# 33697    ZYLINSKA,  KLAUDIA                          POLICE OFFICER
# 33698    ZYMANTAS,  LAURA C                          POLICE OFFICER
# 33699     ZYMANTAS,  MARK E                          POLICE OFFICER
# 33700   ZYRKOWSKI,  CARLO E                          POLICE OFFICER
#
#       department full_or_part-time salary_or_hourly  typical_hours  \
# 1         POLICE                 F           Salary            NaN
# 4         POLICE                 F           Salary            NaN
# 6         POLICE                 F           Salary            NaN
# 7         POLICE                 F           Salary            NaN
# 9         POLICE                 F           Salary            NaN
# ...          ...               ...              ...            ...
# 33696     POLICE                 F           Salary            NaN
# 33697     POLICE                 F           Salary            NaN
# 33698     POLICE                 F           Salary            NaN
# 33699     POLICE                 F           Salary            NaN
# 33700     POLICE                 F           Salary            NaN
#
#        annual_salary  hourly_rate
# 1            93354.0          NaN
# 4            90024.0          NaN
# 6           111444.0          NaN
# 7           103932.0          NaN
# 9            95736.0          NaN
# ...              ...          ...
# 33696        80016.0          NaN
# 33697        72510.0          NaN
# 33698        76266.0          NaN
# 33699        90024.0          NaN
# 33700        93354.0          NaN
#
# [13850 rows x 8 columns]

# %%
# dropping the Nan in 'salary_emp_police'
salary_emp_police1 = salary_emp_police['annual_salary'].dropna()
salary_emp_police1.isna().sum()
# Out:
# 0

# %%
# Your code here:
# Null Hypothesis is that Department of POLICE having the mean salary of $86000/year
# The alternate hypothesis is that there are total of 13826 rows which has a department of police out of which
# only 8421 getting the salary > 86000/year.

mean = np.mean(salary_emp_police1)
print('Mean of Annual Salary for Police department: ', mean)
std_dev = np.std(salary_emp_police1)
print('Standard Deviation of Annual Salary for Police department: ', std_dev)

stat, pval = ttest_1samp(salary_emp_police1, 86000)
print('stat is  ', stat)
print('pvalue for the two-tailed test is ', pval)

print('pvalue for the one-tailed test is ', pval/2)

"""The null hypothesis is rejected because the p-value is very low"""
# Out:
# Mean of Annual Salary for Police department:  88834.25632865615
# Standard Deviation of Annual Salary for Police department:  17994.573433877755
# stat is   18.519537603296808
# pvalue for the two-tailed test is  1.178882027843547e-75
# pvalue for the one-tailed test is  5.894410139217735e-76
# 'The null hypothesis is rejected because the p-value is very low'

# %% [markdown]
# Using the `crosstab` function, find the department that has the most hourly workers.

# %%
                                                                                                
# STREETS & SAN has the most hourly workers.# Your code here:
department_hourly = hourly.pivot_table(index=['department'],values = ['salary_or_hourly'], aggfunc={'salary_or_hourly':'count'})
department_hourly['salary_or_hourly'].sort_values(ascending = False)
# Out:
# department
# OEMC                  1077
# STREETS & SAN          402
# FAMILY & SUPPORT       356
# PUBLIC LIBRARY         347
# AVIATION               229
# DAIS                   130
# CITY COUNCIL            72
# WATER MGMNT             62
# LAW                     47
# POLICE                  24
# MAYOR'S OFFICE          17
# ANIMAL CONTRL           12
# CULTURAL AFFAIRS        10
# BUSINESS AFFAIRS         7
# HOUSING & ECON DEV       3
# BUDGET & MGMT            2
# DISABILITIES             1
# TRANSPORTN               1
# FINANCE                  1
# Name: salary_or_hourly, dtype: int64

# %% [markdown]
# The workers from the department with the most hourly workers have complained that their hourly wage is less than $35/hour. Using a one sample t-test, test this one-sided hypothesis at the 95% confidence level.

# %%
employees['department'].unique()
# Out:
# array(['FIRE', 'POLICE', 'FAMILY & SUPPORT', 'WATER MGMNT', 'AVIATION',
#        'TRANSPORTN', 'STREETS & SAN', 'FINANCE', 'LAW', 'CITY COUNCIL',
#        'DAIS', 'OEMC', 'COPA', 'HEALTH', 'BUSINESS AFFAIRS',
#        'HUMAN RESOURCES', 'PUBLIC LIBRARY', 'CULTURAL AFFAIRS', 'HOUSING',
#        'PROCUREMENT', 'BUILDINGS', 'ANIMAL CONTRL', 'CITY CLERK',
#        'HOUSING & ECON DEV', 'BOARD OF ELECTION', 'PUBLIC SAFETY ADMIN',
#        'DISABILITIES', 'INSPECTOR GEN', 'HUMAN RELATIONS',
#        "MAYOR'S OFFICE", 'TREASURER', 'BUDGET & MGMT', 'BOARD OF ETHICS',
#        'POLICE BOARD', 'ADMIN HEARNG', 'LICENSE APPL COMM'], dtype=object)

# %%
# Your code here:

# For reference
streets_san_hourly = hourly.loc[hourly['department'] == 'STREETS & SAN']  # 1846 rows

# hourly.loc[((hourly['Department'] == 'STREETS & SAN') & (hourly['Hourly Rate'] >= 35))] # 1389 rows
streets_san_hourly
# Out:
#                          name               job_titles     department  \
# 49     ABDUL-SHAKUR,  TAHIR J  POOL MOTOR TRUCK DRIVER  STREETS & SAN
# 182            ADAMS,  SHEILA    GENERAL LABORER - DSS  STREETS & SAN
# 294     AJENIFUJA,  OLADIPO I  POOL MOTOR TRUCK DRIVER  STREETS & SAN
# 520           ALLEN,  WILLIAM    GENERAL LABORER - DSS  STREETS & SAN
# 608        ALVARADO,  MARLENE  POOL MOTOR TRUCK DRIVER  STREETS & SAN
# ...                       ...                      ...            ...
# 33379             YU,  TONY Y  POOL MOTOR TRUCK DRIVER  STREETS & SAN
# 33445          ZAMORA,  JESUS    GENERAL LABORER - DSS  STREETS & SAN
# 33497    ZAVALA-AGUIRRE,  JIM             TREE TRIMMER  STREETS & SAN
# 33521         ZAYAS,  ALFREDO  POOL MOTOR TRUCK DRIVER  STREETS & SAN
# 33676         ZUNIGA,  THOMAS    GENERAL LABORER - DSS  STREETS & SAN
#
#       full_or_part-time salary_or_hourly  typical_hours  annual_salary  \
# 49                    P           Hourly           10.0            NaN
# 182                   F           Hourly           40.0            NaN
# 294                   P           Hourly           10.0            NaN
# 520                   F           Hourly           40.0            NaN
# 608                   P           Hourly           10.0            NaN
# ...                 ...              ...            ...            ...
# 33379                 P           Hourly           10.0            NaN
# 33445                 F           Hourly           40.0            NaN
# 33497                 F           Hourly           40.0            NaN
# 33521                 P           Hourly           10.0            NaN
# 33676                 F           Hourly           40.0            NaN
#
#        hourly_rate
# 49           29.96
# 182          23.74
# 294          29.96
# 520          25.95
# 608          29.96
# ...            ...
# 33379        29.96
# 33445        25.95
# 33497        27.75
# 33521        29.96
# 33676        25.95
#
# [402 rows x 8 columns]

# %%
# Your code here:

# Null hypothesis is that the hourly wage for department with most hourly workers is greater than equal to $35/year
# The alternative hypothesis is its less than $35/hour
mean = streets_san_hourly['hourly_rate'].mean()
print(f"Mean of Hourly rate for STREETS & SAN department: {mean}")
std_dev = streets_san_hourly['hourly_rate'].std()
print(f"Standard Deviation  of Hourly rate for STREETS & SAN department: {std_dev}")

stat, pval = ttest_1samp(streets_san_hourly['hourly_rate'], 35)
print(pval/2)
print(stat)

"""The null hypothesis is rejected because the p-value is very low"""
# Out:
# Mean of Hourly rate for STREETS & SAN department: 25.679353233830724
# Standard Deviation  of Hourly rate for STREETS & SAN department: 3.3012672817326356
# 1.2134524468094693e-193
# -56.60807521013664
# 'The null hypothesis is rejected because the p-value is very low'

# %% [markdown]
# # Challenge 3: To practice - Constructing Confidence Intervals
#
# While testing our hypothesis is a great way to gather empirical evidence for accepting or rejecting the hypothesis, another way to gather evidence is by creating a confidence interval. A confidence interval gives us information about the true mean of the population. So for a 95% confidence interval, we are 95% sure that the mean of the population is within the confidence interval.
# ).
#
# To read more about confidence intervals, click [here](https://en.wikipedia.org/wiki/Confidence_interval).
#
#
# In the cell below, we will construct a 95% confidence interval for the mean hourly wage of all hourly workers.
#
# The confidence interval is computed in SciPy using the `t.interval` function. You can read more about this function [here](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.t.html).
#
# To compute the confidence interval of the hourly wage, use the 0.95 for the confidence level, number of rows - 1 for degrees of freedom, the mean of the sample for the location parameter and the standard error for the scale. The standard error can be computed using [this](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.sem.html) function in SciPy.

# %%
hourly = employees[(employees['salary_or_hourly'] == 'Hourly')]
hourly = hourly['hourly_rate']
hourly
# Out:
# 2        13.00
# 5        37.45
# 15       40.78
# 16       38.52
# 21       34.98
#          ...
# 33676    25.95
# 33678    43.72
# 33681    51.43
# 33684    49.35
# 33688    37.45
# Name: hourly_rate, Length: 8174, dtype: float64

# %%
import scipy.stats

confidence_level = 0.95
degrees_freedom = len(hourly) - 1  # or, for large values of sample size, just use that (no of samples - 1)
sample_mean = np.mean(hourly)
# note that we use the standard error of the sample 
# as an estimate of the standard error of the population (which is used in the theoretical formula)
sample_standard_error = scipy.stats.sem(hourly) # sem = standard error of the mean = std(mean)/sqrt(samplesize) std(mean )is no of patients in the sample
confidence_interval = scipy.stats.t.interval(confidence_level, 
                                             degrees_freedom, 
                                             sample_mean, 
                                             sample_standard_error)

# %%
print( 'confidence interval is ', confidence_interval, '.' )
# Out:
# confidence interval is  (34.29839539204361, 34.874504045197305) .

# %% [markdown]
# Now construct the 95% confidence interval for all salaried employeed in the police in the cell below.

# %%
salary_emp_police = employees[((employees['department'] == 'POLICE') | (employees['department'] == 'POLICE BOARD'))]
salary_emp_police
# Out:
#                        name                              job_titles  \
# 1         AFFANEH,  MAHIR A                          POLICE OFFICER
# 4           AGEE,  LAWRENCE                          POLICE OFFICER
# 6         AGNEW,  MELISSA M                                SERGEANT
# 7         AGOSTA,  JOSEPH J  POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 9         AGOSTINI,  LUIS R                                ASST DIR
# ...                     ...                                     ...
# 33696  ZYLINSKA,  KATARZYNA                          POLICE OFFICER
# 33697    ZYLINSKA,  KLAUDIA                          POLICE OFFICER
# 33698    ZYMANTAS,  LAURA C                          POLICE OFFICER
# 33699     ZYMANTAS,  MARK E                          POLICE OFFICER
# 33700   ZYRKOWSKI,  CARLO E                          POLICE OFFICER
#
#       department full_or_part-time salary_or_hourly  typical_hours  \
# 1         POLICE                 F           Salary            NaN
# 4         POLICE                 F           Salary            NaN
# 6         POLICE                 F           Salary            NaN
# 7         POLICE                 F           Salary            NaN
# 9         POLICE                 F           Salary            NaN
# ...          ...               ...              ...            ...
# 33696     POLICE                 F           Salary            NaN
# 33697     POLICE                 F           Salary            NaN
# 33698     POLICE                 F           Salary            NaN
# 33699     POLICE                 F           Salary            NaN
# 33700     POLICE                 F           Salary            NaN
#
#        annual_salary  hourly_rate
# 1            93354.0          NaN
# 4            90024.0          NaN
# 6           111444.0          NaN
# 7           103932.0          NaN
# 9            95736.0          NaN
# ...              ...          ...
# 33696        80016.0          NaN
# 33697        72510.0          NaN
# 33698        76266.0          NaN
# 33699        90024.0          NaN
# 33700        93354.0          NaN
#
# [13850 rows x 8 columns]

# %%
salary_emp_police1 = salary_emp_police['annual_salary'].dropna()

# %%
import scipy.stats

confidence_level = 0.95
degrees_freedom = len(salary_emp_police1) - 1  # or, for large values of sample size, just use that (no of samples - 1)
sample_mean = np.mean(salary_emp_police1)
# note that we use the standard error of the sample 
# as an estimate of the standard error of the population (which is used in the theoretical formula)
sample_standard_error = scipy.stats.sem(salary_emp_police1) # sem = standard error of the mean = std(mean)/sqrt(samplesize) std(mean )is no of patients in the sample
confidence_interval = scipy.stats.t.interval(confidence_level, 
                                             degrees_freedom, 
                                             sample_mean, 
                                             sample_standard_error)

# %%
print( 'confidence interval is ', confidence_interval, '.' )
# Out:
# confidence interval is  (88534.27439465115, 89134.23826266115) .

# %% [markdown]
# # Bonus Challenge - Hypothesis Tests of Proportions
#
# Another type of one sample test is a hypothesis test of proportions. In this test, we examine whether the proportion of a group in our sample is significantly different than a fraction.
#
# You can read more about one sample proportion tests [here](http://sphweb.bumc.bu.edu/otlt/MPH-Modules/BS/SAS/SAS6-CategoricalData/SAS6-CategoricalData2.html).
#
# In the cell below, use the `proportions_ztest` function from `statsmodels` to perform a hypothesis test that will determine whether the number of hourly workers in the City of Chicago is significantly different from 25% at the 95% confidence level.

# %%
# Your code here:

import numpy as np
from statsmodels.stats.proportion import proportions_ztest
